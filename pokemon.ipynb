# %%
# !pip install icrawler
# Out:
# 2022-06-17 05:33:19,937 - INFO - parser - parser-001 is waiting for new page urls
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# 2022-06-17 05:33:21,943 - INFO - parser - parser-001 is waiting for new page urls

# %%
from icrawler.builtin import BingImageCrawler
# 画像のダウンロード
bing_crawler = BingImageCrawler(parser_threads=2, downloader_threads=4, storage={'root_dir': 'dog'})
bing_crawler.crawl(keyword='dog', filters=None, offset=0, max_num=10)
# Out:
# 2022-06-17 05:33:27,483 - INFO - icrawler.crawler - start crawling...
# 2022-06-17 05:33:27,488 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2022-06-17 05:33:27,506 - INFO - feeder - thread feeder-001 exit
# 2022-06-17 05:33:27,506 - INFO - icrawler.crawler - starting 2 parser threads...
# 2022-06-17 05:33:27,518 - INFO - icrawler.crawler - starting 4 downloader threads...
# 2022-06-17 05:33:27,561 - ERROR - parser - Exception caught when fetching page https://www.bing.com/images/async?q=dog&first=0, error: <_SSLMethod.PROTOCOL_TLS_CLIENT: 16>, remaining retry times: 2
# 2022-06-17 05:33:27,587 - ERROR - parser - Exception caught when fetching page https://www.bing.com/images/async?q=dog&first=0, error: <_SSLMethod.PROTOCOL_TLS_CLIENT: 16>, remaining retry times: 1
# 2022-06-17 05:33:27,620 - ERROR - parser - Exception caught when fetching page https://www.bing.com/images/async?q=dog&first=0, error: <_SSLMethod.PROTOCOL_TLS_CLIENT: 16>, remaining retry times: 0
# ...

# %%
# !python -V
# Out:
# Python 3.7.13

# %%
# フォルダのzip化
# !zip -r /content/download.zip /content/data
